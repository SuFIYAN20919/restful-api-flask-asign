# %% [raw]
# 1 .What is a RESTful API ?
# -A **RESTful API** (Representational State Transfer API) is a type of web API that follows the principles and constraints of REST architecture, which is a standardized way of designing networked applications. It allows different software systems to communicate over the internet using standard HTTP methods.
#
# ### Key Concepts of RESTful API:
#
# 1. **Client-Server Architecture**:
#    The client (frontend) and server (backend) are separate. The client sends requests, and the server returns responses.
#
# 2. **Stateless**:
#    Each request from the client to the server must contain all the information needed to understand and process the request. The server does not store any session information.
#
# 3. **Uniform Interface**:
#    REST uses standard HTTP methods:
#
#    * `GET`: Retrieve data
#    * `POST`: Create new data
#    * `PUT`: Update existing data
#    * `DELETE`: Remove data
#
# 4. **Resources and URIs**:
#    Everything is treated as a **resource** (e.g., users, products), and each resource is identified by a **URI** (Uniform Resource Identifier), like:
#
#    ```
#    GET /users/123     → Get user with ID 123
#    POST /users        → Create a new user
#    ```
#
# 5. **Representation**:
#    Data is usually returned in formats like **JSON** or **XML**.
#
# 6. **Stateless Communication**:
#    Each API call is independent, and no client context is stored on the server between requests.
#
# 7. **Cacheable**:
#    Responses must define whether they are cacheable or not to improve performance.
#
# ---
#
# ### Example:
#
# A RESTful API for a blog might expose the following endpoints:
#
# | HTTP Method | Endpoint   | Description            |
# | ----------- | ---------- | ---------------------- |
# | GET         | `/posts`   | List all blog posts    |
# | GET         | `/posts/1` | Get details of post #1 |
# | POST        | `/posts`   | Create a new blog post |
# | PUT         | `/posts/1` | Update post #1         |
# | DELETE      | `/posts/1` | Delete post #1         |
#
# ---

# %% [raw]
# 2. Explain the concept of API specification ?
# -An API specification is a detailed, formal document that defines how software components should interact with each other via an Application Programming Interface (API). It describes what an API does, how to use it, what inputs it accepts, what outputs it returns, and how errors are handled.
# Key Elements of an API Specification:
# Endpoints:
#
# Define the URLs or URIs used to access the API.
#
# Example: GET /users, POST /orders
#
# HTTP Methods:
#
# Specify the type of action being performed.
#
# Common methods: GET, POST, PUT, DELETE, PATCH
#
# Request Parameters:
#
# Inputs to the API.
#
# Types: Path parameters, query parameters, headers, body (JSON/XML)
#
# Response Format:
#
# Data returned by the API.
#
# Usually in JSON or XML.
#
# Includes status codes (200 OK, 404 Not Found, etc.)
#
# Authentication & Authorization:
#
# Defines how users or systems prove their identity (e.g., API keys, OAuth tokens).
#
# Error Handling:
#
# Lists error codes and messages (e.g., 400 Bad Request, 500 Internal Server Error).
#
# Data Models / Schemas:
#
# Describes the structure of request and response bodies (e.g., fields, types, constraints).

# %% [raw]
# 3.What is Flask, and why is it popular for building APIs?
# -Flask is a lightweight and flexible web framework written in Python. It is especially popular for building RESTful APIs and small-to-medium web applications.
#
# Feature	Why It Matters
# Lightweight and Simple	Minimal setup; great for beginners and quick projects.
# Flexible	No strict project structure; developers have full control.
# Built-in Development Server	Run and test APIs easily without external servers.
# RESTful Routing	Easy to map routes to functions using decorators like @app.route().
# JSON Support	Built-in support for handling JSON data (common in APIs).
# Extensible	Can integrate with SQLAlchemy, Marshmallow, Flask-JWT, etc.
# Strong Community & Documentation	Well-documented with a large ecosystem of tutorials and extensions.
#
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# @app.route('/greet', methods=['GET'])
# def greet():
#     name = request.args.get('name', 'Guest')
#     return jsonify({'message': f'Hello, {name}!'})
#
# if __name__ == '__main__':
#     app.run(debug=True)

# %% [raw]
# 4.What is routing in Flask?
# -In Flask, routing refers to the process of associating a URL with a specific function (called a view function). This allows Flask to respond appropriately when a user visits a particular URL in the browser.
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route('/')
# def home():
#     return "Welcome to the Home Page!"
#
# @app.route('/about')
# def about():
#     return "This is the About Page."

# %% [raw]
# 5.How do you create a simple Flask application?
# Creating a simple Flask application is easy and a great way to get started with web development in Python. Here’s a step-by-step guide:
#
# ---
#
# ### ✅ Step 1: **Install Flask**
#
# Make sure you have Python installed, then install Flask via pip:
#
# ```bash
# pip install flask
# ```
#
# ---
#
# ### ✅ Step 2: **Create a Simple Flask App**
#
# Create a new Python file, e.g., `app.py`, and add the following code:
#
# ```python
# from flask import Flask
#
# # Create a Flask instance
# app = Flask(__name__)
#
# # Define a route for the home page
# @app.route('/')
# def home():
#     return 'Hello, Flask!'
#
# # Run the application
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# ---
#
# ### ✅ Step 3: **Run the Flask App**
#
# In your terminal, navigate to the folder containing `app.py` and run:
#
# ```bash
# python app.py
# ```
#
# You’ll see something like:
#
# ```
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# ```
#
# Open your browser and go to `http://127.0.0.1:5000/` — you should see:
#
# ```
# Hello, Flask!
# ```
#
# ---
#
# ### ✅ Step 4 (Optional): **Add Another Route**
#
# You can add more routes easily:
#
# ```python
# @app.route('/about')
# def about():
#     return 'This is the About page.'
# ```
#
# Now visiting `http://127.0.0.1:5000/about` will show that message.
#
# ---

# %% [raw]
# 6.What are HTTP methods used in RESTful APIs?
# HTTP methods are fundamental to RESTful APIs, as they define the type of operation a client wants to perform on a resource. Here are the most commonly used HTTP methods in RESTful APIs:
#
# ---
#
# ### 1. **GET**
#
# * **Purpose**: Retrieve data from the server.
# * **Safe & Idempotent**: Yes.
# * **Example**: `GET /users/123` → Fetch user with ID 123.
#
# ---
#
# ### 2. **POST**
#
# * **Purpose**: Create a new resource on the server.
# * **Safe**: No
# * **Idempotent**: No
# * **Example**: `POST /users` with a JSON body to create a new user.
#
# ---
#
# ### 3. **PUT**
#
# * **Purpose**: Update an existing resource or create if it doesn't exist (full update).
# * **Idempotent**: Yes
# * **Example**: `PUT /users/123` with full user data.
#
# ---
#
# ### 4. **PATCH**
#
# * **Purpose**: Partially update an existing resource.
# * **Idempotent**: Generally yes
# * **Example**: `PATCH /users/123` with only the fields that need updating.
#
# ---
#
# ### 5. **DELETE**
#
# * **Purpose**: Delete a resource from the server.
# * **Idempotent**: Yes
# * **Example**: `DELETE /users/123` → Delete user with ID 123.
#
# ---
#
# ### 6. **HEAD**
#
# * **Purpose**: Same as GET but only retrieves headers, not the body.
# * **Use Case**: Check if a resource exists or inspect metadata.
#
# ---
#
# ### 7. **OPTIONS**
#
# * **Purpose**: Describe the communication options available for the target resource.
# * **Use Case**: Often used in CORS preflight requests.
#
# ---
#
# ### Summary Table
#
# | Method  | Operation          | Idempotent | Safe |
# | ------- | ------------------ | ---------- | ---- |
# | GET     | Read               | Yes        | Yes  |
# | POST    | Create             | No         | No   |
# | PUT     | Update/Replace     | Yes        | No   |
# | PATCH   | Partial Update     | Yes\*      | No   |
# | DELETE  | Delete             | Yes        | No   |
# | HEAD    | Headers Only       | Yes        | Yes  |
# | OPTIONS | Query capabilities | Yes        | Yes  |
#
# ---

# %% [raw]
# 7. What is the purpose of the @app.route() decorator in Flask
# -The `@app.route()` decorator in Flask is used to **bind a specific URL to a function**. This means when a user visits that URL in their web browser, Flask will execute the associated function (called a *view function*) and return the result to the client.
#
# ### Purpose:
#
# * **Define routes (URLs)** for your web application.
# * **Connect URLs to view functions** that generate responses.
#
# ---
#
# ### Syntax:
#
# ```python
# from flask import Flask
# app = Flask(__name__)
#
# @app.route('/')
# def home():
#     return "Welcome to the homepage!"
# ```
#
# In this example:
#
# * `@app.route('/')` tells Flask that when someone visits the root URL (`/`), it should call the `home()` function.
# * The `home()` function returns the response that will be shown in the browser.
#
# ---
#
# ### You can also specify:
#
# * **URL variables**: e.g., `@app.route('/user/<username>')`
# * **Methods** (GET, POST): e.g., `@app.route('/submit', methods=['POST'])`
#
# ---
#
# ### Summary:
#
# The `@app.route()` decorator is essential for routing in Flask. It helps Flask understand **which function should handle which URL request**, allowing you to build dynamic and interactive web applications.

# %% [raw]
# 8.What is the difference between GET and POST HTTP methods
# -The **GET** and **POST** methods are two of the most commonly used HTTP methods in web development, and they serve different purposes in how data is sent between a client (usually a browser) and a server.
#
# ---
#
# ###  **GET Method**
#
# **Purpose**: Used to **request data** from a server.
#
# **Key Features**:
#
# * **Data sent in URL**: Data is appended to the URL as **query parameters** (e.g., `example.com/search?q=python`).
# * **Visible data**: The data is visible in the address bar, so it’s **not secure** for sensitive information.
# * **Cached**: Can be cached by browsers.
# * **Bookmarkable**: URLs with GET parameters can be bookmarked.
# * **Idempotent**: Calling it multiple times doesn’t change the state of the server.
#
# **Example Use Case**: Searching for information (e.g., Google search).
#
# ---
#
# ###  **POST Method**
#
# **Purpose**: Used to **send data** to the server, often to create or update a resource.
#
# **Key Features**:
#
# * **Data sent in body**: Data is included in the body of the HTTP request, not in the URL.
# * **More secure**: Better for sending sensitive information (e.g., passwords), but still needs HTTPS for full security.
# * **Not cached**: Typically not cached by browsers.
# * **Not bookmarkable**: The data sent is not part of the URL.
# * **Not idempotent**: Multiple submissions can lead to multiple changes on the server.
#
# **Example Use Case**: Submitting a login form or creating a new user account.
#
# ---
#
# ###  Summary Table
#
# | Feature       | GET                    | POST                     |
# | ------------- | ---------------------- | ------------------------ |
# | Purpose       | Retrieve data          | Send data                |
# | Data location | URL (query string)     | HTTP request body        |
# | Visibility    | Visible in browser URL | Hidden from URL          |
# | Security      | Less secure            | More secure (with HTTPS) |
# | Bookmarkable  | Yes                    | No                       |
# | Cached        | Yes                    | No                       |
# | Idempotent    | Yes                    | No                       |
# | Common usage  | Reading/fetching data  | Sending/submitting data  |

# %% [raw]
# 9.How do you handle errors in Flask APIs
# -Handling errors properly in Flask APIs is essential for debugging, logging, and sending meaningful responses to clients. Here's how you can handle errors in Flask:
#
# ---
#
# ##  1. **Using `@app.errorhandler` Decorator**
#
# You can create custom error handlers for specific HTTP error codes like 404 or 500.
#
# ```python
# from flask import Flask, jsonify
#
# app = Flask(__name__)
#
# @app.errorhandler(404)
# def not_found(error):
#     return jsonify({'error': 'Not found'}), 404
#
# @app.errorhandler(500)
# def internal_error(error):
#     return jsonify({'error': 'Internal Server Error'}), 500
# ```
#
# ---
#
# ##  2. **Handling Exceptions with `try-except`**
#
# Use try-except blocks in routes or functions to catch and respond to specific errors.
#
# ```python
# @app.route('/divide')
# def divide():
#     try:
#         a = int(request.args.get('a'))
#         b = int(request.args.get('b'))
#         result = a / b
#         return jsonify({'result': result})
#     except ZeroDivisionError:
#         return jsonify({'error': 'Division by zero'}), 400
#     except Exception as e:
#         return jsonify({'error': str(e)}), 500
# ```
#
# ---
#
# ##  3. **Creating Custom Exception Classes**
#
# Define your own exceptions and register handlers for them.
#
# ```python
# class InvalidUsage(Exception):
#     status_code = 400
#
#     def __init__(self, message, status_code=None):
#         super().__init__(message)
#         self.message = message
#         if status_code:
#             self.status_code = status_code
#
# @app.errorhandler(InvalidUsage)
# def handle_invalid_usage(error):
#     response = jsonify({'error': error.message})
#     response.status_code = error.status_code
#     return response
# ```
#
# ---
#
# ##  4. **Using `abort()` for Immediate Error Response**
#
# Flask’s `abort()` function helps to return HTTP errors quickly.
#
# ```python
# from flask import abort
#
# @app.route('/secure')
# def secure():
#     abort(403)  # Forbidden
# ```
#
# ---
#
# ##  5. **Returning Consistent Error Responses**
#
# Maintain consistency in your API responses by using a common format.
#
# ```python
# @app.errorhandler(Exception)
# def handle_exception(e):
#     response = {
#         'error': 'An unexpected error occurred',
#         'message': str(e)
#     }
#     return jsonify(response), 500
# ```
#
# ---

# %% [raw]
# 10.How do you connect Flask to a SQL database
# -To connect **Flask** to a **SQL database**, you typically use an ORM (Object Relational Mapper) like **SQLAlchemy**, or use **raw SQL** with a connector. Here's a step-by-step guide using **Flask with SQLAlchemy**, which is the most common approach.
#
# ---
#
# ##  Step-by-Step: Connecting Flask to SQL Database using SQLAlchemy
#
# ### 1. **Install Flask and Flask-SQLAlchemy**
#
# ```bash
# pip install Flask Flask-SQLAlchemy
# ```
#
# ---
#
# ### 2. **Create Your Flask App**
#
# Here's an example using **SQLite** (can be adapted to MySQL, PostgreSQL, etc.)
#
# ```python
# from flask import Flask
# from flask_sqlalchemy import SQLAlchemy
#
# app = Flask(__name__)
#
# # Configure the database URI (e.g., SQLite here)
# app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///mydatabase.db'
# app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False  # Optional
#
# # Initialize the database object
# db = SQLAlchemy(app)
# ```
#
# ---
#
# ### 3. **Define Your Database Models**
#
# ```python
# class User(db.Model):
#     id = db.Column(db.Integer, primary_key=True)
#     username = db.Column(db.String(80), nullable=False)
#     email = db.Column(db.String(120), unique=True, nullable=False)
#
#     def __repr__(self):
#         return f'<User {self.username}>'
# ```
#
# ---
#
# ### 4. **Create the Database**
#
# Run this once (or use Flask CLI or a separate script):
#
# ```python
# with app.app_context():
#     db.create_all()
# ```
#
# ---
#
# ### 5. **Use the Database in Routes**
#
# ```python
# @app.route('/add_user/<name>/<email>')
# def add_user(name, email):
#     new_user = User(username=name, email=email)
#     db.session.add(new_user)
#     db.session.commit()
#     return f"Added user {name}"
# ```
#
# ---
#
# ## To Use MySQL or PostgreSQL
#
# Change the `SQLALCHEMY_DATABASE_URI` like this:
#
# ### For MySQL:
#
# ```python
# app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+pymysql://username:password@localhost/dbname'
# ```
#
# ### For PostgreSQL:
#
# ```python
# app.config['SQLALCHEMY_DATABASE_URI'] = 'postgresql://username:password@localhost/dbname'
# ```
#
# You may need to install additional drivers:
#
# ```bash
# pip install pymysql           # For MySQL
# pip install psycopg2-binary   # For PostgreSQL
# ```
#
# ---

# %% [raw]
# 11.What is the role of Flask-SQLAlchemy
# -Flask-SQLAlchemy is an extension for Flask that adds support for SQLAlchemy, a powerful and flexible Object Relational Mapper (ORM) for Python. It simplifies the integration of databases into Flask applications.

# %% [raw]
# 12.What are Flask blueprints, and how are they useful
# -Flask Blueprints are a way to organize your Flask application into modular components. Think of them as mini applications within your main app. Each blueprint can contain its own routes, templates, static files, and more.

# %%
pip install flask
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1.How do you create a basic Flask application

from flask import Flask

app = Flask(__name__)  # Create an instance of the Flask class

@app.route('/')  # Define a route for the home page
def home():
    return 'Hello, Flask!'  # Response for the home page

if __name__ == '__main__':
    app.run(debug=True)  # Run the app in debug mode
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [raw]
# # 2. How do you serve static files like images or CSS in Flask
# your_project/
# │
# ├── app.py
# ├── static/
# │   ├── css/
# │   │   └── style.css
# │   ├── images/
# │   │   └── logo.png
# │   └── js/
# │       └── script.js
# └── templates/
#     └── index.html
# # app.py
# from flask import Flask, render_template
#
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     return render_template('index.html')
#
# if __name__ == '__main__':
#     app.run(debug=True)

# %%
# 4.How do you define different routes with different HTTP methods in Flask
@app.route('/submit', methods=['GET', 'POST'])
def submit():
    if request.method == 'POST':
        return "Form submitted via POST"
    else:
        return "Submit page accessed via GET"

# %%
# 5. How do you render HTML templates in Flask
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
# 6.How do you handle forms in Flask
from flask import Flask, render_template, request

app = Flask(__name__)

@app.route('/form', methods=['GET', 'POST'])
def form():
    if request.method == 'POST':
        name = request.form['name']
        return f"Hello, {name}!"
    return '''
        <form method="post">
            Name: <input type="text" name="name">
            <input type="submit">
        </form>
    '''

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
# 7.How can you validate form data in Flask
from flask_wtf import FlaskForm
from wtforms import StringField, PasswordField, SubmitField
from wtforms.validators import DataRequired, Length, Email

class LoginForm(FlaskForm):
    email = StringField('Email', validators=[DataRequired(), Email()])
    password = PasswordField('Password', validators=[DataRequired(), Length(min=6)])
    submit = SubmitField('Login')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 2
#       1 # 7.How can you validate form data in Flask
# ----> 2 from flask_wtf import FlaskForm
#       3 from wtforms import StringField, PasswordField, SubmitField
#       4 from wtforms.validators import DataRequired, Length, Email
#
# ModuleNotFoundError: No module named 'flask_wtf'

# %%
# 8.How do you manage sessions in Flask
#In Flask, session management is used to store and retrieve data specific to a user across multiple requests. 
#Flask provides a built-in session object to handle sessions, 
#which is a dictionary that allows you to store information like login state, user preferences, etc
@app.route('/login')
def login():
    session['username'] = 'sufiyan'
    return 'Logged in successfully!'
